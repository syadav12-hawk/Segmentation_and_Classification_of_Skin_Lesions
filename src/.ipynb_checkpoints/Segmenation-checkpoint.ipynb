# %% [markdown]
# ## CS512 - Segmentation and classification of skin lesions
# ### Contains:
# #### 1. Unet
# #### --------------------------------------
# #### --------------------------------------
# ### Authors:
# #### Sourav Yadav - A20450418
# #### Akshay R - A20442409

# %%
#Load Packages
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import Activation, Dense, BatchNormalization, Dropout, Conv2D, Conv2DTranspose, MaxPooling2D, UpSampling2D, Input, Reshape
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras import backend as K
from tensorflow.keras.optimizers import Adam, SGD
import tensorflow as tf
import numpy as np
import pandas as pd
import glob
import PIL
from PIL import Image
import matplotlib.pyplot as plt
import cv2
# %matplotlib inline

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
from warnings import filterwarnings

filterwarnings('ignore')
plt.rcParams["axes.grid"] = False
np.random.seed(101)
# Out:
# Using TensorFlow backend.

# %%
#Sorting the Files by name
import re
num= re.compile(r'(\d+)')
def numericalSort(value):
    parts = num.split(value)
    parts[1::2] = map(int, parts[1::2])
    return parts

# %%
filelist_trainx = sorted(glob.glob('trainx/*.jpg'), key=numericalSort)
X_train = np.array([np.array(Image.open(fname)) for fname in filelist_trainx])
print(filelist_trainx[21])

filelist_trainy = sorted(glob.glob('trainy/*.jpg'), key=numericalSort)
Y_train = np.array([np.array(Image.open(fname)) for fname in filelist_trainy])
# Out:
# ../input/ph2-resized/trainx/X_img_21.bmp

# %%
#Train and Test Split
x_train, x_test, y_train, y_test = train_test_split(X_train, Y_train, test_size = 0.25, random_state = 101)

# %%
#Few Examples of Skin Lesion
plt.figure(figsize=(20,9))
plt.subplot(2,4,1)
plt.imshow(X_train[0])
plt.subplot(2,4,2)
plt.imshow(X_train[3])
plt.subplot(2,4,3)
plt.imshow(X_train[54])
plt.subplot(2,4,4)
plt.imshow(X_train[77])
plt.subplot(2,4,5)
plt.imshow(X_train[100])
plt.subplot(2,4,6)
plt.imshow(X_train[125])
plt.subplot(2,4,7)
plt.imshow(X_train[130])
plt.subplot(2,4,8)
plt.imshow(X_train[149])
plt.show()

# %%
#Mask Corresponding to Above Images. 
plt.figure(figsize=(20,9))
plt.subplot(2,4,1)
plt.imshow(Y_train[0], cmap = plt.cm.binary_r)
plt.subplot(2,4,2)
plt.imshow(Y_train[3], cmap = plt.cm.binary_r)
plt.subplot(2,4,3)
plt.imshow(Y_train[54], cmap = plt.cm.binary_r)
plt.subplot(2,4,4)
plt.imshow(Y_train[77], cmap = plt.cm.binary_r)
plt.subplot(2,4,5)
plt.imshow(Y_train[100], cmap = plt.cm.binary_r)
plt.subplot(2,4,6)
plt.imshow(Y_train[125], cmap = plt.cm.binary_r)
plt.subplot(2,4,7)
plt.imshow(Y_train[130], cmap = plt.cm.binary_r)
plt.subplot(2,4,8)
plt.imshow(Y_train[149], cmap = plt.cm.binary_r)
plt.show()

# %% [markdown]
# ### Helper functions

# %%
def iou(y_true, y_pred, smooth = 100):
    intersection = K.sum(K.abs(y_true * y_pred), axis=-1)
    sum_ = K.sum(K.square(y_true), axis = -1) + K.sum(K.square(y_pred), axis=-1)
    jac = (intersection + smooth) / (sum_ - intersection + smooth)
    return jac

# %%
def dice_coef(y_true, y_pred, smooth = 100):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

# %%
def precision(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    return precision

# %%
def recall(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    recall = true_positives / (possible_positives + K.epsilon())
    return recall

# %%
def accuracy(y_true, y_pred):
    return K.mean(K.equal(y_true, K.round(y_pred)))

# %%
#Image and its mask Augmentation
def random_rotation(x_image, y_image):
    rows_x,cols_x, chl_x = x_image.shape
    rows_y,cols_y = y_image.shape
    rand_num = np.random.randint(-40,40)
    M1 = cv2.getRotationMatrix2D((cols_x/2,rows_x/2),rand_num,1)
    M2 = cv2.getRotationMatrix2D((cols_y/2,rows_y/2),rand_num,1)
    x_image = cv2.warpAffine(x_image,M1,(cols_x,rows_x))
    y_image = cv2.warpAffine(y_image.astype('float32'),M2,(cols_y,rows_y))
    return x_image, y_image.astype('int')

def horizontal_flip(x_image, y_image):
    x_image = cv2.flip(x_image, 1)
    y_image = cv2.flip(y_image.astype('float32'), 1)
    return x_image, y_image.astype('int')

# %%
def img_augmentation(x_train, y_train):
    x_rotat = []
    y_rotat = []
    x_flip = []
    y_flip = []
    x_nois = []
    for idx in range(len(x_train)):
        x,y = random_rotation(x_train[idx], y_train[idx])
        x_rotat.append(x)
        y_rotat.append(y)
        
        x,y = horizontal_flip(x_train[idx], y_train[idx])
        x_flip.append(x)
        y_flip.append(y)
        return np.array(x_rotat), np.array(y_rotat), np.array(x_flip), np.array(y_flip)

# %%
def img_augmentation(x_test, y_test):
    x_rotat = []
    y_rotat = []
    x_flip = []
    y_flip = []
    x_nois = []
    for idx in range(len(x_test)):
        x,y = random_rotation(x_test[idx], y_test[idx])
        x_rotat.append(x)
        y_rotat.append(y)
        
        x,y = horizontal_flip(x_test[idx], y_test[idx])
        x_flip.append(x)
        y_flip.append(y)

    return np.array(x_rotat), np.array(y_rotat), np.array(x_flip), np.array(y_flip)

# %%
x_rotated, y_rotated, x_flipped, y_flipped = img_augmentation(x_train, y_train)
x_rotated_t, y_rotated_t, x_flipped_t, y_flipped_t = img_augmentation(x_test, y_test)

# %%
img_num = 114
plt.figure(figsize=(12,12))
plt.subplot(3,2,1)
plt.imshow(x_train[img_num])
plt.title('Original Image')
plt.subplot(3,2,2)
plt.imshow(y_train[img_num], plt.cm.binary_r)
plt.title('Original Mask')
plt.subplot(3,2,3)
plt.imshow(x_rotated[img_num])
plt.title('Rotated Image')
plt.subplot(3,2,4)
plt.imshow(y_rotated[img_num], plt.cm.binary_r)
plt.title('Rotated Mask')
plt.subplot(3,2,5)
plt.imshow(x_flipped[img_num])
plt.title('Flipped Image')
plt.subplot(3,2,6)
plt.imshow(y_flipped[img_num], plt.cm.binary_r)
plt.title('Flipped Mask')
plt.show()

# %%
# For training Set
x_train_full = np.concatenate([x_train, x_rotated, x_flipped])
y_train_full = np.concatenate([y_train, y_rotated, y_flipped])

# %%
x_train, x_val, y_train, y_val = train_test_split(x_train_full, y_train_full, test_size = 0.30, random_state = 101)

# %%
print("Length of the Training Set   : {}".format(len(x_train)))
print("Length of the Test Set       : {}".format(len(x_test)))
print("Length of the Validation Set : {}".format(len(x_val)))
# Out:
# Length of the Training Set   : 315
# Length of the Test Set       : 50
# Length of the Validation Set : 135

# %% [markdown]
# ### Unet model

# %%
def unet(epochs_num,savename):

    # Encoding layer
    img_input = Input(shape= (192, 256, 3))
    x = Conv2D(64, (3, 3), padding='same', name='conv1',strides= (1,1))(img_input)
    x = BatchNormalization(name='bn1')(x)
    x = Activation('relu')(x)
    x = Conv2D(64, (3, 3), padding='same', name='conv2')(x)
    x = BatchNormalization(name='bn2')(x)
    x = Activation('relu')(x)
    x = MaxPooling2D()(x)
    
    x = Conv2D(128, (3, 3), padding='same', name='conv3')(x)
    x = BatchNormalization(name='bn3')(x)
    x = Activation('relu')(x)
    x = Conv2D(128, (3, 3), padding='same', name='conv4')(x)
    x = BatchNormalization(name='bn4')(x)
    x = Activation('relu')(x)
    x = MaxPooling2D()(x)

    x = Conv2D(256, (3, 3), padding='same', name='conv5')(x)
    x = BatchNormalization(name='bn5')(x)
    x = Activation('relu')(x)
    x = Conv2D(256, (3, 3), padding='same', name='conv6')(x)
    x = BatchNormalization(name='bn6')(x)
    x = Activation('relu')(x)
    x = Conv2D(256, (3, 3), padding='same', name='conv7')(x)
    x = BatchNormalization(name='bn7')(x)
    x = Activation('relu')(x)
    x = MaxPooling2D()(x)

    x = Conv2D(512, (3, 3), padding='same', name='conv8')(x)
    x = BatchNormalization(name='bn8')(x)
    x = Activation('relu')(x)
    x = Conv2D(512, (3, 3), padding='same', name='conv9')(x)
    x = BatchNormalization(name='bn9')(x)
    x = Activation('relu')(x)
    x = Conv2D(512, (3, 3), padding='same', name='conv10')(x)
    x = BatchNormalization(name='bn10')(x)
    x = Activation('relu')(x)
    x = MaxPooling2D()(x)
    
    x = Conv2D(512, (3, 3), padding='same', name='conv11')(x)
    x = BatchNormalization(name='bn11')(x)
    x = Activation('relu')(x)
    x = Conv2D(512, (3, 3), padding='same', name='conv12')(x)
    x = BatchNormalization(name='bn12')(x)
    x = Activation('relu')(x)
    x = Conv2D(512, (3, 3), padding='same', name='conv13')(x)
    x = BatchNormalization(name='bn13')(x)
    x = Activation('relu')(x)
    x = MaxPooling2D()(x)

    x = Dense(1024, activation = 'relu', name='fc1')(x)
    x = Dense(1024, activation = 'relu', name='fc2')(x)
    
    # Decoding Layer 
    x = UpSampling2D()(x)
    x = Conv2DTranspose(512, (3, 3), padding='same', name='deconv1')(x)
    x = BatchNormalization(name='bn14')(x)
    x = Activation('relu')(x)
    x = Conv2DTranspose(512, (3, 3), padding='same', name='deconv2')(x)
    x = BatchNormalization(name='bn15')(x)
    x = Activation('relu')(x)
    x = Conv2DTranspose(512, (3, 3), padding='same', name='deconv3')(x)
    x = BatchNormalization(name='bn16')(x)
    x = Activation('relu')(x)
    
    x = UpSampling2D()(x)
    x = Conv2DTranspose(512, (3, 3), padding='same', name='deconv4')(x)
    x = BatchNormalization(name='bn17')(x)
    x = Activation('relu')(x)
    x = Conv2DTranspose(512, (3, 3), padding='same', name='deconv5')(x)
    x = BatchNormalization(name='bn18')(x)
    x = Activation('relu')(x)
    x = Conv2DTranspose(256, (3, 3), padding='same', name='deconv6')(x)
    x = BatchNormalization(name='bn19')(x)
    x = Activation('relu')(x)

    x = UpSampling2D()(x)
    x = Conv2DTranspose(256, (3, 3), padding='same', name='deconv7')(x)
    x = BatchNormalization(name='bn20')(x)
    x = Activation('relu')(x)
    x = Conv2DTranspose(256, (3, 3), padding='same', name='deconv8')(x)
    x = BatchNormalization(name='bn21')(x)
    x = Activation('relu')(x)
    x = Conv2DTranspose(128, (3, 3), padding='same', name='deconv9')(x)
    x = BatchNormalization(name='bn22')(x)
    x = Activation('relu')(x)

    x = UpSampling2D()(x)
    x = Conv2DTranspose(128, (3, 3), padding='same', name='deconv10')(x)
    x = BatchNormalization(name='bn23')(x)
    x = Activation('relu')(x)
    x = Conv2DTranspose(64, (3, 3), padding='same', name='deconv11')(x)
    x = BatchNormalization(name='bn24')(x)
    x = Activation('relu')(x)
    
    x = UpSampling2D()(x)
    x = Conv2DTranspose(64, (3, 3), padding='same', name='deconv12')(x)
    x = BatchNormalization(name='bn25')(x)
    x = Activation('relu')(x)
    x = Conv2DTranspose(1, (3, 3), padding='same', name='deconv13')(x)
    x = BatchNormalization(name='bn26')(x)
    x = Activation('sigmoid')(x)
    pred = Reshape((192,256))(x)
    
    model = Model(inputs=img_input, outputs=pred)
    
    model.compile(optimizer= SGD(lr=0.001, momentum=0.9, decay=0.0005, nesterov=False), loss= ["binary_crossentropy"]
                  , metrics=[iou, dice_coef, precision, recall, accuracy])
    model.summary()
    hist = model.fit(x_train, y_train, epochs= epochs_num, batch_size= 18, validation_data= (x_val, y_val), verbose=1)
    
    model.save(savename)
    return model,hist

# %%
model, hist = unet(1, 'unet_1_epoch.h5')
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 192, 256, 3)       0
# _________________________________________________________________
# conv1 (Conv2D)               (None, 192, 256, 64)      1792
# _________________________________________________________________
# bn1 (BatchNormalization)     (None, 192, 256, 64)      256
# _________________________________________________________________
# activation_1 (Activation)    (None, 192, 256, 64)      0
# _________________________________________________________________
# conv2 (Conv2D)               (None, 192, 256, 64)      36928
# _________________________________________________________________
# bn2 (BatchNormalization)     (None, 192, 256, 64)      256
# _________________________________________________________________
# activation_2 (Activation)    (None, 192, 256, 64)      0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 96, 128, 64)       0
# _________________________________________________________________
# conv3 (Conv2D)               (None, 96, 128, 128)      73856
# _________________________________________________________________
# bn3 (BatchNormalization)     (None, 96, 128, 128)      512
# _________________________________________________________________
# activation_3 (Activation)    (None, 96, 128, 128)      0
# _________________________________________________________________
# conv4 (Conv2D)               (None, 96, 128, 128)      147584
# _________________________________________________________________
# bn4 (BatchNormalization)     (None, 96, 128, 128)      512
# _________________________________________________________________
# activation_4 (Activation)    (None, 96, 128, 128)      0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 48, 64, 128)       0
# _________________________________________________________________
# conv5 (Conv2D)               (None, 48, 64, 256)       295168
# _________________________________________________________________
# bn5 (BatchNormalization)     (None, 48, 64, 256)       1024
# _________________________________________________________________
# activation_5 (Activation)    (None, 48, 64, 256)       0
# _________________________________________________________________
# conv6 (Conv2D)               (None, 48, 64, 256)       590080
# _________________________________________________________________
# bn6 (BatchNormalization)     (None, 48, 64, 256)       1024
# _________________________________________________________________
# activation_6 (Activation)    (None, 48, 64, 256)       0
# _________________________________________________________________
# conv7 (Conv2D)               (None, 48, 64, 256)       590080
# _________________________________________________________________
# bn7 (BatchNormalization)     (None, 48, 64, 256)       1024
# _________________________________________________________________
# activation_7 (Activation)    (None, 48, 64, 256)       0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 24, 32, 256)       0
# _________________________________________________________________
# conv8 (Conv2D)               (None, 24, 32, 512)       1180160
# _________________________________________________________________
# bn8 (BatchNormalization)     (None, 24, 32, 512)       2048
# _________________________________________________________________
# activation_8 (Activation)    (None, 24, 32, 512)       0
# _________________________________________________________________
# conv9 (Conv2D)               (None, 24, 32, 512)       2359808
# _________________________________________________________________
# bn9 (BatchNormalization)     (None, 24, 32, 512)       2048
# _________________________________________________________________
# activation_9 (Activation)    (None, 24, 32, 512)       0
# _________________________________________________________________
# conv10 (Conv2D)              (None, 24, 32, 512)       2359808
# _________________________________________________________________
# bn10 (BatchNormalization)    (None, 24, 32, 512)       2048
# _________________________________________________________________
# activation_10 (Activation)   (None, 24, 32, 512)       0
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 12, 16, 512)       0
# _________________________________________________________________
# conv11 (Conv2D)              (None, 12, 16, 512)       2359808
# _________________________________________________________________
# bn11 (BatchNormalization)    (None, 12, 16, 512)       2048
# _________________________________________________________________
# activation_11 (Activation)   (None, 12, 16, 512)       0
# _________________________________________________________________
# conv12 (Conv2D)              (None, 12, 16, 512)       2359808
# _________________________________________________________________
# bn12 (BatchNormalization)    (None, 12, 16, 512)       2048
# _________________________________________________________________
# activation_12 (Activation)   (None, 12, 16, 512)       0
# _________________________________________________________________
# conv13 (Conv2D)              (None, 12, 16, 512)       2359808
# _________________________________________________________________
# bn13 (BatchNormalization)    (None, 12, 16, 512)       2048
# _________________________________________________________________
# activation_13 (Activation)   (None, 12, 16, 512)       0
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 6, 8, 512)         0
# _________________________________________________________________
# fc1 (Dense)                  (None, 6, 8, 1024)        525312
# _________________________________________________________________
# fc2 (Dense)                  (None, 6, 8, 1024)        1049600
# _________________________________________________________________
# up_sampling2d_1 (UpSampling2 (None, 12, 16, 1024)      0
# _________________________________________________________________
# deconv1 (Conv2DTranspose)    (None, 12, 16, 512)       4719104
# _________________________________________________________________
# bn14 (BatchNormalization)    (None, 12, 16, 512)       2048
# _________________________________________________________________
# activation_14 (Activation)   (None, 12, 16, 512)       0
# _________________________________________________________________
# deconv2 (Conv2DTranspose)    (None, 12, 16, 512)       2359808
# _________________________________________________________________
# bn15 (BatchNormalization)    (None, 12, 16, 512)       2048
# _________________________________________________________________
# activation_15 (Activation)   (None, 12, 16, 512)       0
# _________________________________________________________________
# deconv3 (Conv2DTranspose)    (None, 12, 16, 512)       2359808
# _________________________________________________________________
# bn16 (BatchNormalization)    (None, 12, 16, 512)       2048
# _________________________________________________________________
# activation_16 (Activation)   (None, 12, 16, 512)       0
# _________________________________________________________________
# up_sampling2d_2 (UpSampling2 (None, 24, 32, 512)       0
# _________________________________________________________________
# deconv4 (Conv2DTranspose)    (None, 24, 32, 512)       2359808
# _________________________________________________________________
# bn17 (BatchNormalization)    (None, 24, 32, 512)       2048
# _________________________________________________________________
# activation_17 (Activation)   (None, 24, 32, 512)       0
# _________________________________________________________________
# deconv5 (Conv2DTranspose)    (None, 24, 32, 512)       2359808
# _________________________________________________________________
# bn18 (BatchNormalization)    (None, 24, 32, 512)       2048
# _________________________________________________________________
# activation_18 (Activation)   (None, 24, 32, 512)       0
# _________________________________________________________________
# deconv6 (Conv2DTranspose)    (None, 24, 32, 256)       1179904
# _________________________________________________________________
# bn19 (BatchNormalization)    (None, 24, 32, 256)       1024
# _________________________________________________________________
# activation_19 (Activation)   (None, 24, 32, 256)       0
# _________________________________________________________________
# up_sampling2d_3 (UpSampling2 (None, 48, 64, 256)       0
# _________________________________________________________________
# deconv7 (Conv2DTranspose)    (None, 48, 64, 256)       590080
# _________________________________________________________________
# bn20 (BatchNormalization)    (None, 48, 64, 256)       1024
# _________________________________________________________________
# activation_20 (Activation)   (None, 48, 64, 256)       0
# _________________________________________________________________
# deconv8 (Conv2DTranspose)    (None, 48, 64, 256)       590080
# _________________________________________________________________
# bn21 (BatchNormalization)    (None, 48, 64, 256)       1024
# _________________________________________________________________
# activation_21 (Activation)   (None, 48, 64, 256)       0
# _________________________________________________________________
# deconv9 (Conv2DTranspose)    (None, 48, 64, 128)       295040
# _________________________________________________________________
# bn22 (BatchNormalization)    (None, 48, 64, 128)       512
# _________________________________________________________________
# activation_22 (Activation)   (None, 48, 64, 128)       0
# _________________________________________________________________
# up_sampling2d_4 (UpSampling2 (None, 96, 128, 128)      0
# _________________________________________________________________
# deconv10 (Conv2DTranspose)   (None, 96, 128, 128)      147584
# _________________________________________________________________
# bn23 (BatchNormalization)    (None, 96, 128, 128)      512
# _________________________________________________________________
# activation_23 (Activation)   (None, 96, 128, 128)      0
# _________________________________________________________________
# deconv11 (Conv2DTranspose)   (None, 96, 128, 64)       73792
# _________________________________________________________________
# bn24 (BatchNormalization)    (None, 96, 128, 64)       256
# _________________________________________________________________
# activation_24 (Activation)   (None, 96, 128, 64)       0
# _________________________________________________________________
# up_sampling2d_5 (UpSampling2 (None, 192, 256, 64)      0
# _________________________________________________________________
# deconv12 (Conv2DTranspose)   (None, 192, 256, 64)      36928
# _________________________________________________________________
# bn25 (BatchNormalization)    (None, 192, 256, 64)      256
# _________________________________________________________________
# activation_25 (Activation)   (None, 192, 256, 64)      0
# _________________________________________________________________
# deconv13 (Conv2DTranspose)   (None, 192, 256, 1)       577
# _________________________________________________________________
# bn26 (BatchNormalization)    (None, 192, 256, 1)       4
# _________________________________________________________________
# activation_26 (Activation)   (None, 192, 256, 1)       0
# _________________________________________________________________
# reshape_1 (Reshape)          (None, 192, 256)          0
# =================================================================
# Total params: 33,393,669
# Trainable params: 33,377,795
# Non-trainable params: 15,874
# _________________________________________________________________
# Train on 315 samples, validate on 135 samples
# Epoch 1/1
# 315/315 [==============================] - 18s 58ms/step - loss: 0.7012 - iou: 0.6935 - dice_coef: 0.4364 - precision: 0.4179 - recall: 0.6077 - accuracy: 0.6036 - val_loss: 0.8098 - val_iou: 0.6869 - val_dice_coef: 0.3906 - val_precision: 0.4126 - val_recall: 0.4496 - val_accuracy: 0.6156

# %% [markdown]
# ### Define and fit the model

# %%
# Encoding layer
img_input = Input(shape= (192, 256, 3))
x = Conv2D(64, (3, 3), padding='same', name='conv1',strides= (1,1))(img_input)
x = BatchNormalization(name='bn1')(x)
x = Activation('relu')(x)
x = Conv2D(64, (3, 3), padding='same', name='conv2')(x)
x = BatchNormalization(name='bn2')(x)
x = Activation('relu')(x)
x = MaxPooling2D()(x)

x = Conv2D(128, (3, 3), padding='same', name='conv3')(x)
x = BatchNormalization(name='bn3')(x)
x = Activation('relu')(x)
x = Conv2D(128, (3, 3), padding='same', name='conv4')(x)
x = BatchNormalization(name='bn4')(x)
x = Activation('relu')(x)
x = MaxPooling2D()(x)

x = Conv2D(256, (3, 3), padding='same', name='conv5')(x)
x = BatchNormalization(name='bn5')(x)
x = Activation('relu')(x)
x = Conv2D(256, (3, 3), padding='same', name='conv6')(x)
x = BatchNormalization(name='bn6')(x)
x = Activation('relu')(x)
x = Conv2D(256, (3, 3), padding='same', name='conv7')(x)
x = BatchNormalization(name='bn7')(x)
x = Activation('relu')(x)
x = MaxPooling2D()(x)

x = Conv2D(512, (3, 3), padding='same', name='conv8')(x)
x = BatchNormalization(name='bn8')(x)
x = Activation('relu')(x)
x = Conv2D(512, (3, 3), padding='same', name='conv9')(x)
x = BatchNormalization(name='bn9')(x)
x = Activation('relu')(x)
x = Conv2D(512, (3, 3), padding='same', name='conv10')(x)
x = BatchNormalization(name='bn10')(x)
x = Activation('relu')(x)
x = MaxPooling2D()(x)

x = Conv2D(512, (3, 3), padding='same', name='conv11')(x)
x = BatchNormalization(name='bn11')(x)
x = Activation('relu')(x)
x = Conv2D(512, (3, 3), padding='same', name='conv12')(x)
x = BatchNormalization(name='bn12')(x)
x = Activation('relu')(x)
x = Conv2D(512, (3, 3), padding='same', name='conv13')(x)
x = BatchNormalization(name='bn13')(x)
x = Activation('relu')(x)
x = MaxPooling2D()(x)

x = Dense(1024, activation = 'relu', name='fc1')(x)
x = Dense(1024, activation = 'relu', name='fc2')(x)

# Decoding Layer 
x = UpSampling2D()(x)
x = Conv2DTranspose(512, (3, 3), padding='same', name='deconv1')(x)
x = BatchNormalization(name='bn14')(x)
x = Activation('relu')(x)
x = Conv2DTranspose(512, (3, 3), padding='same', name='deconv2')(x)
x = BatchNormalization(name='bn15')(x)
x = Activation('relu')(x)
x = Conv2DTranspose(512, (3, 3), padding='same', name='deconv3')(x)
x = BatchNormalization(name='bn16')(x)
x = Activation('relu')(x)

x = UpSampling2D()(x)
x = Conv2DTranspose(512, (3, 3), padding='same', name='deconv4')(x)
x = BatchNormalization(name='bn17')(x)
x = Activation('relu')(x)
x = Conv2DTranspose(512, (3, 3), padding='same', name='deconv5')(x)
x = BatchNormalization(name='bn18')(x)
x = Activation('relu')(x)
x = Conv2DTranspose(256, (3, 3), padding='same', name='deconv6')(x)
x = BatchNormalization(name='bn19')(x)
x = Activation('relu')(x)

x = UpSampling2D()(x)
x = Conv2DTranspose(256, (3, 3), padding='same', name='deconv7')(x)
x = BatchNormalization(name='bn20')(x)
x = Activation('relu')(x)
x = Conv2DTranspose(256, (3, 3), padding='same', name='deconv8')(x)
x = BatchNormalization(name='bn21')(x)
x = Activation('relu')(x)
x = Conv2DTranspose(128, (3, 3), padding='same', name='deconv9')(x)
x = BatchNormalization(name='bn22')(x)
x = Activation('relu')(x)

x = UpSampling2D()(x)
x = Conv2DTranspose(128, (3, 3), padding='same', name='deconv10')(x)
x = BatchNormalization(name='bn23')(x)
x = Activation('relu')(x)
x = Conv2DTranspose(64, (3, 3), padding='same', name='deconv11')(x)
x = BatchNormalization(name='bn24')(x)
x = Activation('relu')(x)

x = UpSampling2D()(x)
x = Conv2DTranspose(64, (3, 3), padding='same', name='deconv12')(x)
x = BatchNormalization(name='bn25')(x)
x = Activation('relu')(x)
x = Conv2DTranspose(1, (3, 3), padding='same', name='deconv13')(x)
x = BatchNormalization(name='bn26')(x)
x = Activation('sigmoid')(x)
pred = Reshape((192,256))(x)

# %%
model, hist = unet(epochs_num= 100, savename= 'unet_100_epoch.h5')
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         (None, 192, 256, 3)       0
# _________________________________________________________________
# conv1 (Conv2D)               (None, 192, 256, 64)      1792
# _________________________________________________________________
# bn1 (BatchNormalization)     (None, 192, 256, 64)      256
# _________________________________________________________________
# activation_53 (Activation)   (None, 192, 256, 64)      0
# _________________________________________________________________
# conv2 (Conv2D)               (None, 192, 256, 64)      36928
# _________________________________________________________________
# bn2 (BatchNormalization)     (None, 192, 256, 64)      256
# _________________________________________________________________
# activation_54 (Activation)   (None, 192, 256, 64)      0
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 96, 128, 64)       0
# _________________________________________________________________
# conv3 (Conv2D)               (None, 96, 128, 128)      73856
# _________________________________________________________________
# bn3 (BatchNormalization)     (None, 96, 128, 128)      512
# _________________________________________________________________
# activation_55 (Activation)   (None, 96, 128, 128)      0
# _________________________________________________________________
# conv4 (Conv2D)               (None, 96, 128, 128)      147584
# _________________________________________________________________
# bn4 (BatchNormalization)     (None, 96, 128, 128)      512
# _________________________________________________________________
# activation_56 (Activation)   (None, 96, 128, 128)      0
# _________________________________________________________________
# max_pooling2d_12 (MaxPooling (None, 48, 64, 128)       0
# _________________________________________________________________
# conv5 (Conv2D)               (None, 48, 64, 256)       295168
# _________________________________________________________________
# bn5 (BatchNormalization)     (None, 48, 64, 256)       1024
# _________________________________________________________________
# activation_57 (Activation)   (None, 48, 64, 256)       0
# _________________________________________________________________
# conv6 (Conv2D)               (None, 48, 64, 256)       590080
# _________________________________________________________________
# bn6 (BatchNormalization)     (None, 48, 64, 256)       1024
# _________________________________________________________________
# activation_58 (Activation)   (None, 48, 64, 256)       0
# _________________________________________________________________
# conv7 (Conv2D)               (None, 48, 64, 256)       590080
# _________________________________________________________________
# bn7 (BatchNormalization)     (None, 48, 64, 256)       1024
# _________________________________________________________________
# activation_59 (Activation)   (None, 48, 64, 256)       0
# _________________________________________________________________
# max_pooling2d_13 (MaxPooling (None, 24, 32, 256)       0
# _________________________________________________________________
# conv8 (Conv2D)               (None, 24, 32, 512)       1180160
# _________________________________________________________________
# bn8 (BatchNormalization)     (None, 24, 32, 512)       2048
# _________________________________________________________________
# activation_60 (Activation)   (None, 24, 32, 512)       0
# _________________________________________________________________
# conv9 (Conv2D)               (None, 24, 32, 512)       2359808
# _________________________________________________________________
# bn9 (BatchNormalization)     (None, 24, 32, 512)       2048
# _________________________________________________________________
# activation_61 (Activation)   (None, 24, 32, 512)       0
# _________________________________________________________________
# conv10 (Conv2D)              (None, 24, 32, 512)       2359808
# _________________________________________________________________
# bn10 (BatchNormalization)    (None, 24, 32, 512)       2048
# _________________________________________________________________
# activation_62 (Activation)   (None, 24, 32, 512)       0
# _________________________________________________________________
# max_pooling2d_14 (MaxPooling (None, 12, 16, 512)       0
# _________________________________________________________________
# conv11 (Conv2D)              (None, 12, 16, 512)       2359808
# _________________________________________________________________
# bn11 (BatchNormalization)    (None, 12, 16, 512)       2048
# _________________________________________________________________
# activation_63 (Activation)   (None, 12, 16, 512)       0
# _________________________________________________________________
# conv12 (Conv2D)              (None, 12, 16, 512)       2359808
# _________________________________________________________________
# bn12 (BatchNormalization)    (None, 12, 16, 512)       2048
# _________________________________________________________________
# activation_64 (Activation)   (None, 12, 16, 512)       0
# _________________________________________________________________
# conv13 (Conv2D)              (None, 12, 16, 512)       2359808
# _________________________________________________________________
# bn13 (BatchNormalization)    (None, 12, 16, 512)       2048
# _________________________________________________________________
# activation_65 (Activation)   (None, 12, 16, 512)       0
# _________________________________________________________________
# max_pooling2d_15 (MaxPooling (None, 6, 8, 512)         0
# _________________________________________________________________
# fc1 (Dense)                  (None, 6, 8, 1024)        525312
# _________________________________________________________________
# fc2 (Dense)                  (None, 6, 8, 1024)        1049600
# _________________________________________________________________
# up_sampling2d_11 (UpSampling (None, 12, 16, 1024)      0
# _________________________________________________________________
# deconv1 (Conv2DTranspose)    (None, 12, 16, 512)       4719104
# _________________________________________________________________
# bn14 (BatchNormalization)    (None, 12, 16, 512)       2048
# _________________________________________________________________
# activation_66 (Activation)   (None, 12, 16, 512)       0
# _________________________________________________________________
# deconv2 (Conv2DTranspose)    (None, 12, 16, 512)       2359808
# _________________________________________________________________
# bn15 (BatchNormalization)    (None, 12, 16, 512)       2048
# _________________________________________________________________
# activation_67 (Activation)   (None, 12, 16, 512)       0
# _________________________________________________________________
# deconv3 (Conv2DTranspose)    (None, 12, 16, 512)       2359808
# _________________________________________________________________
# bn16 (BatchNormalization)    (None, 12, 16, 512)       2048
# _________________________________________________________________
# activation_68 (Activation)   (None, 12, 16, 512)       0
# _________________________________________________________________
# up_sampling2d_12 (UpSampling (None, 24, 32, 512)       0
# _________________________________________________________________
# deconv4 (Conv2DTranspose)    (None, 24, 32, 512)       2359808
# _________________________________________________________________
# bn17 (BatchNormalization)    (None, 24, 32, 512)       2048
# _________________________________________________________________
# activation_69 (Activation)   (None, 24, 32, 512)       0
# _________________________________________________________________
# deconv5 (Conv2DTranspose)    (None, 24, 32, 512)       2359808
# _________________________________________________________________
# bn18 (BatchNormalization)    (None, 24, 32, 512)       2048
# _________________________________________________________________
# activation_70 (Activation)   (None, 24, 32, 512)       0
# _________________________________________________________________
# deconv6 (Conv2DTranspose)    (None, 24, 32, 256)       1179904
# _________________________________________________________________
# bn19 (BatchNormalization)    (None, 24, 32, 256)       1024
# _________________________________________________________________
# activation_71 (Activation)   (None, 24, 32, 256)       0
# _________________________________________________________________
# up_sampling2d_13 (UpSampling (None, 48, 64, 256)       0
# _________________________________________________________________
# deconv7 (Conv2DTranspose)    (None, 48, 64, 256)       590080
# _________________________________________________________________
# bn20 (BatchNormalization)    (None, 48, 64, 256)       1024
# _________________________________________________________________
# activation_72 (Activation)   (None, 48, 64, 256)       0
# _________________________________________________________________
# deconv8 (Conv2DTranspose)    (None, 48, 64, 256)       590080
# _________________________________________________________________
# bn21 (BatchNormalization)    (None, 48, 64, 256)       1024
# _________________________________________________________________
# activation_73 (Activation)   (None, 48, 64, 256)       0
# _________________________________________________________________
# deconv9 (Conv2DTranspose)    (None, 48, 64, 128)       295040
# _________________________________________________________________
# bn22 (BatchNormalization)    (None, 48, 64, 128)       512
# _________________________________________________________________
# activation_74 (Activation)   (None, 48, 64, 128)       0
# _________________________________________________________________
# up_sampling2d_14 (UpSampling (None, 96, 128, 128)      0
# _________________________________________________________________
# deconv10 (Conv2DTranspose)   (None, 96, 128, 128)      147584
# _________________________________________________________________
# bn23 (BatchNormalization)    (None, 96, 128, 128)      512
# _________________________________________________________________
# activation_75 (Activation)   (None, 96, 128, 128)      0
# _________________________________________________________________
# deconv11 (Conv2DTranspose)   (None, 96, 128, 64)       73792
# _________________________________________________________________
# bn24 (BatchNormalization)    (None, 96, 128, 64)       256
# _________________________________________________________________
# activation_76 (Activation)   (None, 96, 128, 64)       0
# _________________________________________________________________
# up_sampling2d_15 (UpSampling (None, 192, 256, 64)      0
# _________________________________________________________________
# deconv12 (Conv2DTranspose)   (None, 192, 256, 64)      36928
# _________________________________________________________________
# bn25 (BatchNormalization)    (None, 192, 256, 64)      256
# _________________________________________________________________
# activation_77 (Activation)   (None, 192, 256, 64)      0
# _________________________________________________________________
# deconv13 (Conv2DTranspose)   (None, 192, 256, 1)       577
# _________________________________________________________________
# bn26 (BatchNormalization)    (None, 192, 256, 1)       4
# _________________________________________________________________
# activation_78 (Activation)   (None, 192, 256, 1)       0
# _________________________________________________________________
# reshape_3 (Reshape)          (None, 192, 256)          0
# =================================================================
# Total params: 33,393,669
# Trainable params: 33,377,795
# Non-trainable params: 15,874
# _________________________________________________________________
# Train on 315 samples, validate on 135 samples
# Epoch 1/100
# 315/315 [==============================] - 15s 48ms/step - loss: 0.7155 - iou: 0.6887 - dice_coef: 0.4264 - precision: 0.4130 - recall: 0.5579 - accuracy: 0.6031 - val_loss: 0.8523 - val_iou: 0.6565 - val_dice_coef: 0.4094 - val_precision: 0.3647 - val_recall: 0.5455 - val_accuracy: 0.5467
# Epoch 2/100
# 315/315 [==============================] - 7s 23ms/step - loss: 0.5236 - iou: 0.7654 - dice_coef: 0.5171 - precision: 0.6646 - recall: 0.7396 - accuracy: 0.7930 - val_loss: 0.7931 - val_iou: 0.6760 - val_dice_coef: 0.4804 - val_precision: 0.4017 - val_recall: 0.7750 - val_accuracy: 0.5542
# Epoch 3/100
# 315/315 [==============================] - 7s 24ms/step - loss: 0.4704 - iou: 0.7939 - dice_coef: 0.5478 - precision: 0.7553 - recall: 0.7942 - accuracy: 0.8493 - val_loss: 0.6502 - val_iou: 0.7285 - val_dice_coef: 0.5468 - val_precision: 0.4907 - val_recall: 0.8970 - val_accuracy: 0.6684
# Epoch 4/100
# 315/315 [==============================] - 7s 24ms/step - loss: 0.4431 - iou: 0.8088 - dice_coef: 0.5671 - precision: 0.7933 - recall: 0.8239 - accuracy: 0.8737 - val_loss: 0.4413 - val_iou: 0.8114 - val_dice_coef: 0.6112 - val_precision: 0.7109 - val_recall: 0.8753 - val_accuracy: 0.8474
# Epoch 5/100
# 315/315 [==============================] - 7s 24ms/step - loss: 0.4239 - iou: 0.8198 - dice_coef: 0.5787 - precision: 0.8151 - recall: 0.8487 - accuracy: 0.8875 - val_loss: 0.4207 - val_iou: 0.8219 - val_dice_coef: 0.6250 - val_precision: 0.7265 - val_recall: 0.8914 - val_accuracy: 0.8582
# Epoch 6/100
# 315/315 [==============================] - 7s 24ms/step - loss: 0.4066 - iou: 0.8284 - dice_coef: 0.5901 - precision: 0.8384 - recall: 0.8532 - accuracy: 0.8987 - val_loss: 0.4131 - val_iou: 0.8273 - val_dice_coef: 0.6288 - val_precision: 0.7387 - val_recall: 0.9015 - val_accuracy: 0.8672
# Epoch 7/100
# 315/315 [==============================] - 7s 23ms/step - loss: 0.3918 - iou: 0.8371 - dice_coef: 0.6002 - precision: 0.8487 - recall: 0.8683 - accuracy: 0.9068 - val_loss: 0.3990 - val_iou: 0.8351 - val_dice_coef: 0.6361 - val_precision: 0.7544 - val_recall: 0.9050 - val_accuracy: 0.8756
# Epoch 8/100
# 315/315 [==============================] - 7s 23ms/step - loss: 0.3842 - iou: 0.8423 - dice_coef: 0.6046 - precision: 0.8456 - recall: 0.8771 - accuracy: 0.9070 - val_loss: 0.3944 - val_iou: 0.8370 - val_dice_coef: 0.6370 - val_precision: 0.7477 - val_recall: 0.9141 - val_accuracy: 0.8749
# Epoch 9/100
# 315/315 [==============================] - 7s 23ms/step - loss: 0.3663 - iou: 0.8512 - dice_coef: 0.6168 - precision: 0.8706 - recall: 0.8835 - accuracy: 0.9191 - val_loss: 0.3745 - val_iou: 0.8470 - val_dice_coef: 0.6494 - val_precision: 0.7677 - val_recall: 0.9225 - val_accuracy: 0.8867
# Epoch 10/100
# 315/315 [==============================] - 7s 23ms/step - loss: 0.3588 - iou: 0.8556 - dice_coef: 0.6218 - precision: 0.8697 - recall: 0.8876 - accuracy: 0.9195 - val_loss: 0.4767 - val_iou: 0.8045 - val_dice_coef: 0.6295 - val_precision: 0.6287 - val_recall: 0.9664 - val_accuracy: 0.8076
# Epoch 11/100
# 315/315 [==============================] - 7s 23ms/step - loss: 0.3473 - iou: 0.8618 - dice_coef: 0.6300 - precision: 0.8781 - recall: 0.8942 - accuracy: 0.9254 - val_loss: 0.4422 - val_iou: 0.8173 - val_dice_coef: 0.6352 - val_precision: 0.6570 - val_recall: 0.9600 - val_accuracy: 0.8278
# Epoch 12/100
# 315/315 [==============================] - 7s 24ms/step - loss: 0.3433 - iou: 0.8648 - dice_coef: 0.6322 - precision: 0.8799 - recall: 0.8911 - accuracy: 0.9247 - val_loss: 0.3967 - val_iou: 0.8387 - val_dice_coef: 0.6470 - val_precision: 0.7075 - val_recall: 0.9556 - val_accuracy: 0.8604
# Epoch 13/100
# 315/315 [==============================] - 7s 24ms/step - loss: 0.3301 - iou: 0.8712 - dice_coef: 0.6429 - precision: 0.8845 - recall: 0.9025 - accuracy: 0.9301 - val_loss: 0.3748 - val_iou: 0.8501 - val_dice_coef: 0.6518 - val_precision: 0.7388 - val_recall: 0.9509 - val_accuracy: 0.8775
# Epoch 14/100
# 315/315 [==============================] - 7s 24ms/step - loss: 0.3220 - iou: 0.8761 - dice_coef: 0.6496 - precision: 0.8853 - recall: 0.9116 - accuracy: 0.9326 - val_loss: 0.3461 - val_iou: 0.8633 - val_dice_coef: 0.6680 - val_precision: 0.7730 - val_recall: 0.9458 - val_accuracy: 0.8945
# Epoch 15/100
# 315/315 [==============================] - 7s 23ms/step - loss: 0.3180 - iou: 0.8779 - dice_coef: 0.6508 - precision: 0.8915 - recall: 0.9035 - accuracy: 0.9324 - val_loss: 0.3336 - val_iou: 0.8706 - val_dice_coef: 0.6704 - val_precision: 0.7996 - val_recall: 0.9331 - val_accuracy: 0.9045
# Epoch 16/100
# 315/315 [==============================] - 7s 23ms/step - loss: 0.3079 - iou: 0.8838 - dice_coef: 0.6608 - precision: 0.8932 - recall: 0.9161 - accuracy: 0.9368 - val_loss: 0.3184 - val_iou: 0.8785 - val_dice_coef: 0.6698 - val_precision: 0.8319 - val_recall: 0.9221 - val_accuracy: 0.9158
# Epoch 17/100
# 315/315 [==============================] - 7s 24ms/step - loss: 0.3005 - iou: 0.8877 - dice_coef: 0.6675 - precision: 0.8911 - recall: 0.9225 - accuracy: 0.9381 - val_loss: 0.3096 - val_iou: 0.8813 - val_dice_coef: 0.6850 - val_precision: 0.8233 - val_recall: 0.9309 - val_accuracy: 0.9147
# Epoch 18/100
# 315/315 [==============================] - 7s 24ms/step - loss: 0.2946 - iou: 0.8906 - dice_coef: 0.6709 - precision: 0.9091 - recall: 0.9101 - accuracy: 0.9403 - val_loss: 0.2901 - val_iou: 0.8922 - val_dice_coef: 0.6819 - val_precision: 0.8907 - val_recall: 0.8833 - val_accuracy: 0.9270
# Epoch 19/100
# 315/315 [==============================] - 7s 23ms/step - loss: 0.2861 - iou: 0.8950 - dice_coef: 0.6777 - precision: 0.9105 - recall: 0.9207 - accuracy: 0.9445 - val_loss: 0.3021 - val_iou: 0.8875 - val_dice_coef: 0.6857 - val_precision: 0.8382 - val_recall: 0.9234 - val_accuracy: 0.9183
# Epoch 20/100
# 315/315 [==============================] - 7s 24ms/step - loss: 0.2811 - iou: 0.8979 - dice_coef: 0.6838 - precision: 0.9061 - recall: 0.9257 - accuracy: 0.9443 - val_loss: 0.2927 - val_iou: 0.8916 - val_dice_coef: 0.6860 - val_precision: 0.8513 - val_recall: 0.9275 - val_accuracy: 0.9258
# Epoch 21/100
# 315/315 [==============================] - 7s 24ms/step - loss: 0.2788 - iou: 0.8989 - dice_coef: 0.6842 - precision: 0.9073 - recall: 0.9227 - accuracy: 0.9440 - val_loss: 0.2821 - val_iou: 0.8962 - val_dice_coef: 0.6937 - val_precision: 0.8663 - val_recall: 0.9185 - val_accuracy: 0.9295
# Epoch 22/100
# 315/315 [==============================] - 7s 23ms/step - loss: 0.2769 - iou: 0.9002 - dice_coef: 0.6866 - precision: 0.9086 - recall: 0.9169 - accuracy: 0.9420 - val_loss: 0.2686 - val_iou: 0.9040 - val_dice_coef: 0.6966 - val_precision: 0.9042 - val_recall: 0.9021 - val_accuracy: 0.9381
# Epoch 23/100
# 315/315 [==============================] - 7s 23ms/step - loss: 0.2635 - iou: 0.9064 - dice_coef: 0.6981 - precision: 0.9147 - recall: 0.9320 - accuracy: 0.9497 - val_loss: 0.2757 - val_iou: 0.9004 - val_dice_coef: 0.6998 - val_precision: 0.8642 - val_recall: 0.9304 - val_accuracy: 0.9309
# Epoch 24/100
# 315/315 [==============================] - 7s 24ms/step - loss: 0.2647 - iou: 0.9059 - dice_coef: 0.6971 - precision: 0.9181 - recall: 0.9250 - accuracy: 0.9471 - val_loss: 0.2645 - val_iou: 0.9057 - val_dice_coef: 0.7051 - val_precision: 0.8907 - val_recall: 0.9132 - val_accuracy: 0.9367
# Epoch 25/100
# 315/315 [==============================] - 7s 24ms/step - loss: 0.2522 - iou: 0.9122 - dice_coef: 0.7070 - precision: 0.9251 - recall: 0.9328 - accuracy: 0.9543 - val_loss: 0.2675 - val_iou: 0.9053 - val_dice_coef: 0.6909 - val_precision: 0.9228 - val_recall: 0.8769 - val_accuracy: 0.9368
# Epoch 26/100
# 315/315 [==============================] - 7s 23ms/step - loss: 0.2553 - iou: 0.9108 - dice_coef: 0.7069 - precision: 0.9119 - recall: 0.9336 - accuracy: 0.9486 - val_loss: 0.2756 - val_iou: 0.9016 - val_dice_coef: 0.7015 - val_precision: 0.8535 - val_recall: 0.9301 - val_accuracy: 0.9274
# Epoch 27/100
# 315/315 [==============================] - 7s 23ms/step - loss: 0.2510 - iou: 0.9126 - dice_coef: 0.7097 - precision: 0.9148 - recall: 0.9344 - accuracy: 0.9502 - val_loss: 0.2562 - val_iou: 0.9105 - val_dice_coef: 0.7074 - val_precision: 0.9064 - val_recall: 0.8984 - val_accuracy: 0.9381
# Epoch 28/100
# 315/315 [==============================] - 7s 24ms/step - loss: 0.2375 - iou: 0.9199 - dice_coef: 0.7214 - precision: 0.9318 - recall: 0.9398 - accuracy: 0.9580 - val_loss: 0.2597 - val_iou: 0.9080 - val_dice_coef: 0.7178 - val_precision: 0.8648 - val_recall: 0.9323 - val_accuracy: 0.9326
# Epoch 29/100
# 315/315 [==============================] - 7s 24ms/step - loss: 0.2436 - iou: 0.9165 - dice_coef: 0.7164 - precision: 0.9207 - recall: 0.9321 - accuracy: 0.9514 - val_loss: 0.2560 - val_iou: 0.9103 - val_dice_coef: 0.7188 - val_precision: 0.8699 - val_recall: 0.9318 - val_accuracy: 0.9345
# Epoch 30/100
# 315/315 [==============================] - 7s 24ms/step - loss: 0.2321 - iou: 0.9225 - dice_coef: 0.7275 - precision: 0.9294 - recall: 0.9425 - accuracy: 0.9579 - val_loss: 0.2559 - val_iou: 0.9104 - val_dice_coef: 0.7188 - val_precision: 0.8655 - val_recall: 0.9390 - val_accuracy: 0.9344
# Epoch 31/100
# 315/315 [==============================] - 7s 24ms/step - loss: 0.2348 - iou: 0.9207 - dice_coef: 0.7240 - precision: 0.9224 - recall: 0.9345 - accuracy: 0.9538 - val_loss: 0.2444 - val_iou: 0.9160 - val_dice_coef: 0.7212 - val_precision: 0.9043 - val_recall: 0.9104 - val_accuracy: 0.9406
# Epoch 32/100
# 315/315 [==============================] - 7s 24ms/step - loss: 0.2272 - iou: 0.9245 - dice_coef: 0.7310 - precision: 0.9293 - recall: 0.9421 - accuracy: 0.9582 - val_loss: 0.2483 - val_iou: 0.9137 - val_dice_coef: 0.7238 - val_precision: 0.8758 - val_recall: 0.9370 - val_accuracy: 0.9377
# Epoch 33/100
# 315/315 [==============================] - 7s 24ms/step - loss: 0.2232 - iou: 0.9264 - dice_coef: 0.7352 - precision: 0.9312 - recall: 0.9428 - accuracy: 0.9591 - val_loss: 0.2421 - val_iou: 0.9167 - val_dice_coef: 0.7301 - val_precision: 0.8853 - val_recall: 0.9305 - val_accuracy: 0.9396
# Epoch 34/100
# 315/315 [==============================] - 7s 23ms/step - loss: 0.2223 - iou: 0.9271 - dice_coef: 0.7375 - precision: 0.9253 - recall: 0.9448 - accuracy: 0.9579 - val_loss: 0.2369 - val_iou: 0.9197 - val_dice_coef: 0.7323 - val_precision: 0.8913 - val_recall: 0.9308 - val_accuracy: 0.9419
# Epoch 35/100
# 315/315 [==============================] - 7s 23ms/step - loss: 0.2171 - iou: 0.9294 - dice_coef: 0.7414 - precision: 0.9371 - recall: 0.9408 - accuracy: 0.9602 - val_loss: 0.2438 - val_iou: 0.9153 - val_dice_coef: 0.7388 - val_precision: 0.8570 - val_recall: 0.9484 - val_accuracy: 0.9333
# Epoch 36/100
# 315/315 [==============================] - 7s 24ms/step - loss: 0.2190 - iou: 0.9284 - dice_coef: 0.7408 - precision: 0.9322 - recall: 0.9377 - accuracy: 0.9572 - val_loss: 0.2487 - val_iou: 0.9127 - val_dice_coef: 0.7322 - val_precision: 0.8546 - val_recall: 0.9420 - val_accuracy: 0.9304
# Epoch 37/100
# 315/315 [==============================] - 7s 24ms/step - loss: 0.2131 - iou: 0.9311 - dice_coef: 0.7459 - precision: 0.9364 - recall: 0.9405 - accuracy: 0.9601 - val_loss: 0.2540 - val_iou: 0.9106 - val_dice_coef: 0.7258 - val_precision: 0.8499 - val_recall: 0.9423 - val_accuracy: 0.9289
# Epoch 38/100
# 315/315 [==============================] - 7s 24ms/step - loss: 0.2083 - iou: 0.9334 - dice_coef: 0.7509 - precision: 0.9337 - recall: 0.9479 - accuracy: 0.9616 - val_loss: 0.2492 - val_iou: 0.9142 - val_dice_coef: 0.7305 - val_precision: 0.8556 - val_recall: 0.9428 - val_accuracy: 0.9310
# Epoch 39/100
# 315/315 [==============================] - 7s 24ms/step - loss: 0.2083 - iou: 0.9333 - dice_coef: 0.7511 - precision: 0.9307 - recall: 0.9471 - accuracy: 0.9601 - val_loss: 0.2354 - val_iou: 0.9211 - val_dice_coef: 0.7346 - val_precision: 0.8891 - val_recall: 0.9243 - val_accuracy: 0.9393
# Epoch 40/100
# 315/315 [==============================] - 7s 24ms/step - loss: 0.2081 - iou: 0.9330 - dice_coef: 0.7513 - precision: 0.9328 - recall: 0.9426 - accuracy: 0.9596 - val_loss: 0.2360 - val_iou: 0.9209 - val_dice_coef: 0.7378 - val_precision: 0.8839 - val_recall: 0.9240 - val_accuracy: 0.9369
# Epoch 41/100
# 315/315 [==============================] - 7s 23ms/step - loss: 0.2012 - iou: 0.9364 - dice_coef: 0.7576 - precision: 0.9375 - recall: 0.9459 - accuracy: 0.9626 - val_loss: 0.2422 - val_iou: 0.9189 - val_dice_coef: 0.7350 - val_precision: 0.8773 - val_recall: 0.9175 - val_accuracy: 0.9331
# Epoch 42/100
# 315/315 [==============================] - 7s 24ms/step - loss: 0.2008 - iou: 0.9366 - dice_coef: 0.7589 - precision: 0.9395 - recall: 0.9432 - accuracy: 0.9618 - val_loss: 0.2392 - val_iou: 0.9201 - val_dice_coef: 0.7341 - val_precision: 0.8927 - val_recall: 0.9035 - val_accuracy: 0.9350
# Epoch 43/100
# 315/315 [==============================] - 7s 23ms/step - loss: 0.1995 - iou: 0.9372 - dice_coef: 0.7595 - precision: 0.9342 - recall: 0.9467 - accuracy: 0.9621 - val_loss: 0.2318 - val_iou: 0.9218 - val_dice_coef: 0.7370 - val_precision: 0.9043 - val_recall: 0.8968 - val_accuracy: 0.9367
# Epoch 44/100
# 315/315 [==============================] - 7s 24ms/step - loss: 0.1999 - iou: 0.9365 - dice_coef: 0.7603 - precision: 0.9339 - recall: 0.9454 - accuracy: 0.9604 - val_loss: 0.2249 - val_iou: 0.9250 - val_dice_coef: 0.7417 - val_precision: 0.9076 - val_recall: 0.9061 - val_accuracy: 0.9412
# Epoch 45/100
# 315/315 [==============================] - 7s 24ms/step - loss: 0.1935 - iou: 0.9396 - dice_coef: 0.7659 - precision: 0.9409 - recall: 0.9468 - accuracy: 0.9636 - val_loss: 0.2257 - val_iou: 0.9247 - val_dice_coef: 0.7442 - val_precision: 0.8986 - val_recall: 0.9085 - val_accuracy: 0.9388
# Epoch 46/100
# 315/315 [==============================] - 7s 24ms/step - loss: 0.1897 - iou: 0.9417 - dice_coef: 0.7701 - precision: 0.9430 - recall: 0.9490 - accuracy: 0.9651 - val_loss: 0.2167 - val_iou: 0.9291 - val_dice_coef: 0.7536 - val_precision: 0.8989 - val_recall: 0.9275 - val_accuracy: 0.9438
# Epoch 47/100
# 315/315 [==============================] - 7s 23ms/step - loss: 0.1918 - iou: 0.9406 - dice_coef: 0.7693 - precision: 0.9386 - recall: 0.9494 - accuracy: 0.9628 - val_loss: 0.2139 - val_iou: 0.9299 - val_dice_coef: 0.7518 - val_precision: 0.9266 - val_recall: 0.9025 - val_accuracy: 0.9456
# Epoch 48/100
# 315/315 [==============================] - 7s 23ms/step - loss: 0.1851 - iou: 0.9436 - dice_coef: 0.7746 - precision: 0.9431 - recall: 0.9520 - accuracy: 0.9662 - val_loss: 0.2147 - val_iou: 0.9297 - val_dice_coef: 0.7501 - val_precision: 0.9351 - val_recall: 0.8885 - val_accuracy: 0.9443
# Epoch 49/100
# 315/315 [==============================] - 7s 23ms/step - loss: 0.1868 - iou: 0.9425 - dice_coef: 0.7740 - precision: 0.9370 - recall: 0.9526 - accuracy: 0.9641 - val_loss: 0.2059 - val_iou: 0.9330 - val_dice_coef: 0.7636 - val_precision: 0.9162 - val_recall: 0.9236 - val_accuracy: 0.9482
# Epoch 50/100
# 315/315 [==============================] - 7s 23ms/step - loss: 0.1834 - iou: 0.9442 - dice_coef: 0.7765 - precision: 0.9454 - recall: 0.9496 - accuracy: 0.9659 - val_loss: 0.2074 - val_iou: 0.9324 - val_dice_coef: 0.7636 - val_precision: 0.9050 - val_recall: 0.9282 - val_accuracy: 0.9462
# Epoch 51/100
# 315/315 [==============================] - 7s 24ms/step - loss: 0.1778 - iou: 0.9469 - dice_coef: 0.7825 - precision: 0.9462 - recall: 0.9555 - accuracy: 0.9680 - val_loss: 0.2082 - val_iou: 0.9326 - val_dice_coef: 0.7605 - val_precision: 0.9048 - val_recall: 0.9312 - val_accuracy: 0.9470
# Epoch 52/100
# 315/315 [==============================] - 7s 24ms/step - loss: 0.1865 - iou: 0.9424 - dice_coef: 0.7753 - precision: 0.9402 - recall: 0.9463 - accuracy: 0.9623 - val_loss: 0.2074 - val_iou: 0.9324 - val_dice_coef: 0.7616 - val_precision: 0.9184 - val_recall: 0.9104 - val_accuracy: 0.9456
# Epoch 53/100
# 315/315 [==============================] - 8s 24ms/step - loss: 0.1821 - iou: 0.9445 - dice_coef: 0.7815 - precision: 0.9370 - recall: 0.9542 - accuracy: 0.9637 - val_loss: 0.2253 - val_iou: 0.9258 - val_dice_coef: 0.7543 - val_precision: 0.8703 - val_recall: 0.9377 - val_accuracy: 0.9354
# Epoch 54/100
# 315/315 [==============================] - 7s 24ms/step - loss: 0.1743 - iou: 0.9480 - dice_coef: 0.7867 - precision: 0.9486 - recall: 0.9524 - accuracy: 0.9678 - val_loss: 0.2033 - val_iou: 0.9338 - val_dice_coef: 0.7703 - val_precision: 0.9063 - val_recall: 0.9267 - val_accuracy: 0.9460
# Epoch 55/100
# 315/315 [==============================] - 7s 24ms/step - loss: 0.1702 - iou: 0.9498 - dice_coef: 0.7905 - precision: 0.9498 - recall: 0.9553 - accuracy: 0.9694 - val_loss: 0.2081 - val_iou: 0.9321 - val_dice_coef: 0.7698 - val_precision: 0.8824 - val_recall: 0.9468 - val_accuracy: 0.9431
# Epoch 56/100
# 315/315 [==============================] - 7s 24ms/step - loss: 0.1713 - iou: 0.9493 - dice_coef: 0.7898 - precision: 0.9466 - recall: 0.9550 - accuracy: 0.9681 - val_loss: 0.2108 - val_iou: 0.9308 - val_dice_coef: 0.7673 - val_precision: 0.8804 - val_recall: 0.9420 - val_accuracy: 0.9409
# Epoch 57/100
# 315/315 [==============================] - 7s 23ms/step - loss: 0.1673 - iou: 0.9510 - dice_coef: 0.7937 - precision: 0.9526 - recall: 0.9544 - accuracy: 0.9701 - val_loss: 0.2111 - val_iou: 0.9312 - val_dice_coef: 0.7641 - val_precision: 0.8964 - val_recall: 0.9208 - val_accuracy: 0.9409
# Epoch 58/100
# 315/315 [==============================] - 7s 24ms/step - loss: 0.1733 - iou: 0.9479 - dice_coef: 0.7893 - precision: 0.9400 - recall: 0.9544 - accuracy: 0.9657 - val_loss: 0.2071 - val_iou: 0.9331 - val_dice_coef: 0.7686 - val_precision: 0.8937 - val_recall: 0.9301 - val_accuracy: 0.9427
# Epoch 59/100
# 315/315 [==============================] - 7s 23ms/step - loss: 0.1740 - iou: 0.9472 - dice_coef: 0.7892 - precision: 0.9413 - recall: 0.9501 - accuracy: 0.9646 - val_loss: 0.2038 - val_iou: 0.9336 - val_dice_coef: 0.7733 - val_precision: 0.8876 - val_recall: 0.9392 - val_accuracy: 0.9430
# Epoch 60/100
# 315/315 [==============================] - 7s 24ms/step - loss: 0.1693 - iou: 0.9498 - dice_coef: 0.7941 - precision: 0.9469 - recall: 0.9514 - accuracy: 0.9669 - val_loss: 0.1994 - val_iou: 0.9352 - val_dice_coef: 0.7734 - val_precision: 0.9238 - val_recall: 0.9057 - val_accuracy: 0.9454
# Epoch 61/100
# 315/315 [==============================] - 8s 24ms/step - loss: 0.1681 - iou: 0.9501 - dice_coef: 0.7943 - precision: 0.9413 - recall: 0.9564 - accuracy: 0.9671 - val_loss: 0.1960 - val_iou: 0.9370 - val_dice_coef: 0.7753 - val_precision: 0.9236 - val_recall: 0.9137 - val_accuracy: 0.9478
# Epoch 62/100
# 315/315 [==============================] - 7s 24ms/step - loss: 0.1633 - iou: 0.9523 - dice_coef: 0.7990 - precision: 0.9514 - recall: 0.9542 - accuracy: 0.9694 - val_loss: 0.1906 - val_iou: 0.9391 - val_dice_coef: 0.7815 - val_precision: 0.9302 - val_recall: 0.9118 - val_accuracy: 0.9496
# Epoch 63/100
# 315/315 [==============================] - 7s 24ms/step - loss: 0.1626 - iou: 0.9527 - dice_coef: 0.7995 - precision: 0.9517 - recall: 0.9543 - accuracy: 0.9694 - val_loss: 0.1949 - val_iou: 0.9381 - val_dice_coef: 0.7742 - val_precision: 0.9367 - val_recall: 0.8997 - val_accuracy: 0.9481
# Epoch 64/100
# 315/315 [==============================] - 7s 24ms/step - loss: 0.1620 - iou: 0.9525 - dice_coef: 0.8019 - precision: 0.9463 - recall: 0.9577 - accuracy: 0.9685 - val_loss: 0.1957 - val_iou: 0.9374 - val_dice_coef: 0.7780 - val_precision: 0.9197 - val_recall: 0.9161 - val_accuracy: 0.9472
# Epoch 65/100
# 315/315 [==============================] - 7s 24ms/step - loss: 0.1631 - iou: 0.9517 - dice_coef: 0.8005 - precision: 0.9423 - recall: 0.9571 - accuracy: 0.9677 - val_loss: 0.1927 - val_iou: 0.9390 - val_dice_coef: 0.7788 - val_precision: 0.9235 - val_recall: 0.9166 - val_accuracy: 0.9488
# Epoch 66/100
# 315/315 [==============================] - 7s 24ms/step - loss: 0.1653 - iou: 0.9506 - dice_coef: 0.7975 - precision: 0.9454 - recall: 0.9512 - accuracy: 0.9665 - val_loss: 0.1910 - val_iou: 0.9396 - val_dice_coef: 0.7825 - val_precision: 0.9192 - val_recall: 0.9189 - val_accuracy: 0.9484
# Epoch 67/100
# 315/315 [==============================] - 7s 24ms/step - loss: 0.1663 - iou: 0.9508 - dice_coef: 0.7995 - precision: 0.9487 - recall: 0.9496 - accuracy: 0.9657 - val_loss: 0.1918 - val_iou: 0.9394 - val_dice_coef: 0.7808 - val_precision: 0.9205 - val_recall: 0.9145 - val_accuracy: 0.9476
# Epoch 68/100
# 315/315 [==============================] - 7s 24ms/step - loss: 0.1664 - iou: 0.9503 - dice_coef: 0.7975 - precision: 0.9434 - recall: 0.9503 - accuracy: 0.9650 - val_loss: 0.1908 - val_iou: 0.9397 - val_dice_coef: 0.7800 - val_precision: 0.9305 - val_recall: 0.9069 - val_accuracy: 0.9486
# Epoch 69/100
# 315/315 [==============================] - 8s 24ms/step - loss: 0.1505 - iou: 0.9576 - dice_coef: 0.8129 - precision: 0.9516 - recall: 0.9638 - accuracy: 0.9727 - val_loss: 0.1908 - val_iou: 0.9392 - val_dice_coef: 0.7809 - val_precision: 0.9278 - val_recall: 0.9076 - val_accuracy: 0.9479
# Epoch 70/100
# 315/315 [==============================] - 7s 24ms/step - loss: 0.1603 - iou: 0.9528 - dice_coef: 0.8042 - precision: 0.9449 - recall: 0.9540 - accuracy: 0.9671 - val_loss: 0.1950 - val_iou: 0.9368 - val_dice_coef: 0.7817 - val_precision: 0.9044 - val_recall: 0.9228 - val_accuracy: 0.9445
# Epoch 71/100
# 315/315 [==============================] - 7s 24ms/step - loss: 0.1507 - iou: 0.9574 - dice_coef: 0.8125 - precision: 0.9516 - recall: 0.9608 - accuracy: 0.9721 - val_loss: 0.2060 - val_iou: 0.9316 - val_dice_coef: 0.7795 - val_precision: 0.8729 - val_recall: 0.9429 - val_accuracy: 0.9382
# Epoch 72/100
# 315/315 [==============================] - 7s 24ms/step - loss: 0.1639 - iou: 0.9509 - dice_coef: 0.8023 - precision: 0.9365 - recall: 0.9550 - accuracy: 0.9645 - val_loss: 0.1912 - val_iou: 0.9390 - val_dice_coef: 0.7848 - val_precision: 0.9144 - val_recall: 0.9138 - val_accuracy: 0.9454
# Epoch 73/100
# 315/315 [==============================] - 7s 23ms/step - loss: 0.1542 - iou: 0.9554 - dice_coef: 0.8107 - precision: 0.9525 - recall: 0.9546 - accuracy: 0.9696 - val_loss: 0.1873 - val_iou: 0.9405 - val_dice_coef: 0.7875 - val_precision: 0.9238 - val_recall: 0.9072 - val_accuracy: 0.9470
# Epoch 74/100
# 315/315 [==============================] - 7s 24ms/step - loss: 0.1517 - iou: 0.9563 - dice_coef: 0.8124 - precision: 0.9492 - recall: 0.9593 - accuracy: 0.9706 - val_loss: 0.1886 - val_iou: 0.9401 - val_dice_coef: 0.7880 - val_precision: 0.9162 - val_recall: 0.9153 - val_accuracy: 0.9462
# Epoch 75/100
# 315/315 [==============================] - 7s 24ms/step - loss: 0.1506 - iou: 0.9571 - dice_coef: 0.8146 - precision: 0.9480 - recall: 0.9598 - accuracy: 0.9703 - val_loss: 0.1923 - val_iou: 0.9396 - val_dice_coef: 0.7894 - val_precision: 0.9019 - val_recall: 0.9269 - val_accuracy: 0.9443
# Epoch 76/100
# 315/315 [==============================] - 7s 24ms/step - loss: 0.1506 - iou: 0.9570 - dice_coef: 0.8149 - precision: 0.9537 - recall: 0.9549 - accuracy: 0.9700 - val_loss: 0.1914 - val_iou: 0.9394 - val_dice_coef: 0.7875 - val_precision: 0.9120 - val_recall: 0.9151 - val_accuracy: 0.9443
# Epoch 77/100
# 315/315 [==============================] - 8s 24ms/step - loss: 0.1477 - iou: 0.9581 - dice_coef: 0.8173 - precision: 0.9497 - recall: 0.9604 - accuracy: 0.9711 - val_loss: 0.1851 - val_iou: 0.9414 - val_dice_coef: 0.7907 - val_precision: 0.9209 - val_recall: 0.9140 - val_accuracy: 0.9474
# Epoch 78/100
# 315/315 [==============================] - 7s 24ms/step - loss: 0.1503 - iou: 0.9566 - dice_coef: 0.8144 - precision: 0.9481 - recall: 0.9585 - accuracy: 0.9699 - val_loss: 0.1846 - val_iou: 0.9416 - val_dice_coef: 0.7915 - val_precision: 0.9287 - val_recall: 0.9094 - val_accuracy: 0.9486
# Epoch 79/100
# 315/315 [==============================] - 7s 24ms/step - loss: 0.1554 - iou: 0.9543 - dice_coef: 0.8103 - precision: 0.9449 - recall: 0.9541 - accuracy: 0.9671 - val_loss: 0.1857 - val_iou: 0.9410 - val_dice_coef: 0.7896 - val_precision: 0.9399 - val_recall: 0.8938 - val_accuracy: 0.9477
# Epoch 80/100
# 315/315 [==============================] - 7s 24ms/step - loss: 0.1473 - iou: 0.9578 - dice_coef: 0.8187 - precision: 0.9480 - recall: 0.9599 - accuracy: 0.9704 - val_loss: 0.1822 - val_iou: 0.9422 - val_dice_coef: 0.7956 - val_precision: 0.9163 - val_recall: 0.9243 - val_accuracy: 0.9491
# Epoch 81/100
# 315/315 [==============================] - 7s 23ms/step - loss: 0.1441 - iou: 0.9592 - dice_coef: 0.8212 - precision: 0.9549 - recall: 0.9578 - accuracy: 0.9719 - val_loss: 0.1814 - val_iou: 0.9423 - val_dice_coef: 0.7968 - val_precision: 0.9173 - val_recall: 0.9214 - val_accuracy: 0.9484
# Epoch 82/100
# 315/315 [==============================] - 7s 24ms/step - loss: 0.1472 - iou: 0.9579 - dice_coef: 0.8187 - precision: 0.9482 - recall: 0.9612 - accuracy: 0.9704 - val_loss: 0.1820 - val_iou: 0.9420 - val_dice_coef: 0.7984 - val_precision: 0.9024 - val_recall: 0.9365 - val_accuracy: 0.9477
# Epoch 83/100
# 315/315 [==============================] - 7s 24ms/step - loss: 0.1513 - iou: 0.9559 - dice_coef: 0.8160 - precision: 0.9461 - recall: 0.9560 - accuracy: 0.9678 - val_loss: 0.2064 - val_iou: 0.9335 - val_dice_coef: 0.7843 - val_precision: 0.8785 - val_recall: 0.9255 - val_accuracy: 0.9356
# Epoch 84/100
# 315/315 [==============================] - 7s 24ms/step - loss: 0.1451 - iou: 0.9585 - dice_coef: 0.8207 - precision: 0.9500 - recall: 0.9596 - accuracy: 0.9709 - val_loss: 0.1818 - val_iou: 0.9417 - val_dice_coef: 0.7959 - val_precision: 0.9222 - val_recall: 0.9146 - val_accuracy: 0.9480
# Epoch 85/100
# 315/315 [==============================] - 7s 24ms/step - loss: 0.1401 - iou: 0.9607 - dice_coef: 0.8259 - precision: 0.9540 - recall: 0.9605 - accuracy: 0.9727 - val_loss: 0.1805 - val_iou: 0.9424 - val_dice_coef: 0.8012 - val_precision: 0.9102 - val_recall: 0.9304 - val_accuracy: 0.9484
# Epoch 86/100
# 315/315 [==============================] - 7s 24ms/step - loss: 0.1405 - iou: 0.9605 - dice_coef: 0.8253 - precision: 0.9563 - recall: 0.9581 - accuracy: 0.9725 - val_loss: 0.1810 - val_iou: 0.9421 - val_dice_coef: 0.8015 - val_precision: 0.9061 - val_recall: 0.9316 - val_accuracy: 0.9473
# Epoch 87/100
# 315/315 [==============================] - 7s 24ms/step - loss: 0.1432 - iou: 0.9590 - dice_coef: 0.8227 - precision: 0.9474 - recall: 0.9619 - accuracy: 0.9711 - val_loss: 0.1781 - val_iou: 0.9436 - val_dice_coef: 0.8012 - val_precision: 0.9173 - val_recall: 0.9262 - val_accuracy: 0.9496
# Epoch 88/100
# 315/315 [==============================] - 7s 24ms/step - loss: 0.1445 - iou: 0.9584 - dice_coef: 0.8212 - precision: 0.9423 - recall: 0.9626 - accuracy: 0.9701 - val_loss: 0.1782 - val_iou: 0.9436 - val_dice_coef: 0.8018 - val_precision: 0.9228 - val_recall: 0.9180 - val_accuracy: 0.9490
# Epoch 89/100
# 315/315 [==============================] - 7s 24ms/step - loss: 0.1377 - iou: 0.9616 - dice_coef: 0.8287 - precision: 0.9582 - recall: 0.9587 - accuracy: 0.9732 - val_loss: 0.1790 - val_iou: 0.9432 - val_dice_coef: 0.8023 - val_precision: 0.9179 - val_recall: 0.9188 - val_accuracy: 0.9477
# Epoch 90/100
# 315/315 [==============================] - 7s 23ms/step - loss: 0.1381 - iou: 0.9609 - dice_coef: 0.8274 - precision: 0.9554 - recall: 0.9592 - accuracy: 0.9729 - val_loss: 0.1755 - val_iou: 0.9445 - val_dice_coef: 0.8052 - val_precision: 0.9219 - val_recall: 0.9205 - val_accuracy: 0.9495
# Epoch 91/100
# 315/315 [==============================] - 7s 24ms/step - loss: 0.1347 - iou: 0.9629 - dice_coef: 0.8309 - precision: 0.9553 - recall: 0.9642 - accuracy: 0.9744 - val_loss: 0.1824 - val_iou: 0.9421 - val_dice_coef: 0.8022 - val_precision: 0.8987 - val_recall: 0.9311 - val_accuracy: 0.9450
# Epoch 92/100
# 315/315 [==============================] - 7s 24ms/step - loss: 0.1381 - iou: 0.9610 - dice_coef: 0.8295 - precision: 0.9525 - recall: 0.9613 - accuracy: 0.9720 - val_loss: 0.1820 - val_iou: 0.9422 - val_dice_coef: 0.8032 - val_precision: 0.8991 - val_recall: 0.9327 - val_accuracy: 0.9454
# Epoch 93/100
# 315/315 [==============================] - 7s 24ms/step - loss: 0.1318 - iou: 0.9642 - dice_coef: 0.8350 - precision: 0.9593 - recall: 0.9637 - accuracy: 0.9752 - val_loss: 0.1824 - val_iou: 0.9419 - val_dice_coef: 0.8038 - val_precision: 0.8999 - val_recall: 0.9306 - val_accuracy: 0.9450
# Epoch 94/100
# 315/315 [==============================] - 8s 24ms/step - loss: 0.1394 - iou: 0.9604 - dice_coef: 0.8290 - precision: 0.9510 - recall: 0.9605 - accuracy: 0.9711 - val_loss: 0.1731 - val_iou: 0.9455 - val_dice_coef: 0.8079 - val_precision: 0.9109 - val_recall: 0.9361 - val_accuracy: 0.9504
# Epoch 95/100
# 315/315 [==============================] - 7s 24ms/step - loss: 0.1423 - iou: 0.9592 - dice_coef: 0.8254 - precision: 0.9487 - recall: 0.9578 - accuracy: 0.9697 - val_loss: 0.1765 - val_iou: 0.9439 - val_dice_coef: 0.8034 - val_precision: 0.9259 - val_recall: 0.9099 - val_accuracy: 0.9482
# Epoch 96/100
# 315/315 [==============================] - 7s 24ms/step - loss: 0.1352 - iou: 0.9621 - dice_coef: 0.8322 - precision: 0.9539 - recall: 0.9616 - accuracy: 0.9728 - val_loss: 0.1748 - val_iou: 0.9446 - val_dice_coef: 0.8059 - val_precision: 0.9241 - val_recall: 0.9136 - val_accuracy: 0.9486
# Epoch 97/100
# 315/315 [==============================] - 7s 23ms/step - loss: 0.1340 - iou: 0.9626 - dice_coef: 0.8340 - precision: 0.9511 - recall: 0.9649 - accuracy: 0.9730 - val_loss: 0.1755 - val_iou: 0.9445 - val_dice_coef: 0.8070 - val_precision: 0.9146 - val_recall: 0.9251 - val_accuracy: 0.9486
# Epoch 98/100
# 315/315 [==============================] - 7s 24ms/step - loss: 0.1302 - iou: 0.9644 - dice_coef: 0.8369 - precision: 0.9588 - recall: 0.9626 - accuracy: 0.9747 - val_loss: 0.1690 - val_iou: 0.9470 - val_dice_coef: 0.8127 - val_precision: 0.9277 - val_recall: 0.9204 - val_accuracy: 0.9516
# Epoch 99/100
# 315/315 [==============================] - 7s 24ms/step - loss: 0.1291 - iou: 0.9648 - dice_coef: 0.8381 - precision: 0.9590 - recall: 0.9632 - accuracy: 0.9752 - val_loss: 0.1693 - val_iou: 0.9469 - val_dice_coef: 0.8118 - val_precision: 0.9193 - val_recall: 0.9308 - val_accuracy: 0.9516
# Epoch 100/100
# 315/315 [==============================] - 7s 24ms/step - loss: 0.1340 - iou: 0.9624 - dice_coef: 0.8352 - precision: 0.9526 - recall: 0.9618 - accuracy: 0.9722 - val_loss: 0.1703 - val_iou: 0.9464 - val_dice_coef: 0.8106 - val_precision: 0.9238 - val_recall: 0.9230 - val_accuracy: 0.9511

# %%
model_100 = Model(inputs=img_input, outputs=pred)
model_100.compile(optimizer= SGD(lr=0.001, momentum=0.9, decay=0.0005, nesterov=False), loss= ["binary_crossentropy"]
              , metrics=[iou, dice_coef, precision, recall, accuracy])

# %%
model_100.load_weights('unet_100_epoch.h5')

# %% [markdown]
# ### Outputs

# %%
print('\n~~~~~~~~~~~~~~~Stats after 100 epoch~~~~~~~~~~~~~~~~~~~')
print('\n-------------On Train Set--------------------------\n')
res = model_100.evaluate(x_train, y_train, batch_size= 18)
print('________________________')
print('IOU:       |   {:.2f}  |'.format(res[1]*100))
print('Dice Coef: |   {:.2f}  |'.format(res[2]*100))
print('Precision: |   {:.2f}  |'.format(res[3]*100))
print('Recall:    |   {:.2f}  |'.format(res[4]*100))
print('Accuracy:  |   {:.2f}  |'.format(res[5]*100))
print("Loss:      |   {:.2f}  |".format(res[0]*100))
print('________________________')
print('\n-------------On Test  Set--------------------------\n')
res = model_100.evaluate(x_test, y_test, batch_size= 18)
print('________________________')
print('IOU:       |   {:.2f}  |'.format(res[1]*100))
print('Dice Coef: |   {:.2f}  |'.format(res[2]*100))
print('Precision: |   {:.2f}  |'.format(res[3]*100))
print('Recall:    |   {:.2f}  |'.format(res[4]*100))
print('Accuracy:  |   {:.2f}  |'.format(res[5]*100))
print("Loss:      |   {:.2f}  |".format(res[0]*100))
print('________________________')
print('\n-------------On validation Set---------------------\n')
res = model_100.evaluate(x_val, y_val, batch_size= 18)
print('________________________')
print('IOU:       |   {:.2f}  |'.format(res[1]*100))
print('Dice Coef: |   {:.2f}  |'.format(res[2]*100))
print('Precision: |   {:.2f}  |'.format(res[3]*100))
print('Recall:    |   {:.2f}  |'.format(res[4]*100))
print('Accuracy:  |   {:.2f}  |'.format(res[5]*100))
print("Loss:      |   {:.2f}  |".format(res[0]*100))
print('________________________')
# Out:
# ~~~~~~~~~~~~~~~Stats after 100 epoch~~~~~~~~~~~~~~~~~~~
#
# -------------On Train Set--------------------------
#
# 315/315 [==============================] - 4s 12ms/step
# ________________________
# IOU:       |   96.97  |
# Dice Coef: |   84.72  |
# Precision: |   96.96  |
# Recall:    |   96.50  |
# Accuracy:  |   97.94  |
# Loss:      |   11.75  |
# ________________________
#
# -------------On Test  Set--------------------------
#
# 50/50 [==============================] - 1s 17ms/step
# ________________________
# IOU:       |   93.41  |
# Dice Coef: |   79.02  |
# Precision: |   90.64  |
# Recall:    |   89.27  |
# Accuracy:  |   93.86  |
# Loss:      |   19.56  |
# ________________________
#
# -------------On validation Set---------------------
#
# 135/135 [==============================] - 1s 7ms/step
# ________________________
# IOU:       |   94.64  |
# Dice Coef: |   81.06  |
# Precision: |   92.38  |
# Recall:    |   92.30  |
# Accuracy:  |   95.11  |
# Loss:      |   17.03  |
# ________________________

# %%
plt.figure(figsize=(20, 14))
plt.suptitle('Training Statistics on Train Set')
plt.subplot(2,2,1)
plt.plot(hist.history['loss'], 'red')
plt.title('Loss')
plt.subplot(2,2,2)
plt.plot(hist.history['accuracy'], 'green')
plt.title('Accuracy')
plt.subplot(2,2,3)
plt.plot(hist.history['val_loss'], 'red')
plt.yticks(list(np.arange(0.0, 1.0, 0.10)))
plt.title('Valdiation Loss')
plt.subplot(2,2,4)
plt.plot(hist.history['val_accuracy'], 'green')
plt.yticks(list(np.arange(0.0, 1.0, 0.10)))
plt.title('Validation Accuracy')
plt.show()

# %%
img_num = 10
img_pred = model_100.predict(x_test[img_num].reshape(1,192,256,3))
plt.figure(figsize=(16,16))
plt.subplot(1,3,1)
plt.imshow(x_test[img_num])
plt.title('Original Image')
plt.subplot(1,3,2)
plt.imshow(y_test[img_num], plt.cm.binary_r)
plt.title('Ground Truth')
plt.subplot(1,3,3)
plt.imshow(img_pred.reshape(192, 256), plt.cm.binary_r)
plt.title('Predicted Output')
plt.show()

# %%
img_num = 36
img_pred = model_100.predict(x_test[img_num].reshape(1,192,256,3))
plt.figure(figsize=(16,16))
plt.subplot(1,3,1)
plt.imshow(x_test[img_num])
plt.title('Original Image')
plt.subplot(1,3,2)
plt.imshow(y_test[img_num], plt.cm.binary_r)
plt.title('Ground Truth')
plt.subplot(1,3,3)
plt.imshow(img_pred.reshape(192, 256), plt.cm.binary_r)
plt.title('Predicted Output')
plt.show()

# %%
img_num = 32
img_pred = model_100.predict(x_test[img_num].reshape(1,192,256,3))
plt.figure(figsize=(16,16))
plt.subplot(1,3,1)
plt.imshow(x_test[img_num])
plt.title('Original Image')
plt.subplot(1,3,2)
plt.imshow(y_test[img_num], plt.cm.binary_r)
plt.title('Ground Truth')
plt.subplot(1,3,3)
plt.imshow(img_pred.reshape(192, 256), plt.cm.binary_r)
plt.title('Predicted Output')
plt.show()

# %%
img_num = 29
img_pred = model_100.predict(x_test[img_num].reshape(1,192,256,3))
plt.figure(figsize=(16,16))
plt.subplot(1,3,1)
plt.imshow(x_test[img_num])
plt.title('Original Image')
plt.subplot(1,3,2)
plt.imshow(y_test[img_num], plt.cm.binary_r)
plt.title('Ground Truth')
plt.subplot(1,3,3)
plt.imshow(img_pred.reshape(192, 256), plt.cm.binary_r)
plt.title('Predicted Output')
plt.show()

# %%
img_num = 21
img_pred = model_100.predict(x_test[img_num].reshape(1,192,256,3))
plt.figure(figsize=(16,16))
plt.subplot(1,3,1)
plt.imshow(x_test[img_num])
plt.title('Original Image')
plt.subplot(1,3,2)
plt.imshow(y_test[img_num], plt.cm.binary_r)
plt.title('Ground Truth')
plt.subplot(1,3,3)
plt.imshow(img_pred.reshape(192, 256), plt.cm.binary_r)
plt.title('Predicted Output')
plt.show()

# %% [markdown]
# ### Enhancement

# %%
def enhance(img):
    sub = (model_100.predict(img.reshape(1,192,256,3))).flatten()

    for i in range(len(sub)):
        if sub[i] > 0.5:
            sub[i] = 1
        else:
            sub[i] = 0
    return sub

# %%
plt.figure(figsize=(12,12))
plt.suptitle('Comparing the Prediction after enhancement')
plt.subplot(3,2,1)
plt.imshow(y_test[21],plt.cm.binary_r)
plt.title('Ground Truth')
plt.subplot(3,2,2)
plt.imshow(enhance(x_test[21]).reshape(192,256), plt.cm.binary_r)
plt.title('Predicted')
plt.subplot(3,2,3)
plt.imshow(y_test[47],plt.cm.binary_r)
plt.title('Ground Truth')
plt.subplot(3,2,4)
plt.imshow(enhance(x_test[47]).reshape(192,256), plt.cm.binary_r)
plt.title('Predicted')
plt.subplot(3,2,5)
plt.imshow(y_test[36],plt.cm.binary_r)
plt.title('Ground Truth')
plt.subplot(3,2,6)
plt.imshow(enhance(x_test[36]).reshape(192,256), plt.cm.binary_r)
plt.title('Predicted')
plt.show()

# %% [markdown]
# ### Applying the mask

# %%
def applyMask(img_num):
    img = x_test[img_num]
    mask = np.array(enhance(img).reshape(192, 256), dtype=np.uint8)
    res = cv2.bitwise_and(img,img,mask = mask)
    
    return res

# %%
img_num = 29
masked_img = applyMask(img_num)
plt.figure(figsize=(16,16))
plt.subplot(1,3,1)
plt.imshow(x_test[img_num])
plt.title('Original Image')
plt.subplot(1,3,2)
plt.imshow(enhance(x_test[img_num]).reshape(192, 256), plt.cm.binary_r)
plt.title('Predicted Mask')
plt.subplot(1,3,3)
plt.imshow(masked_img, plt.cm.binary_r)
plt.title('Segmented Output')
plt.show()
